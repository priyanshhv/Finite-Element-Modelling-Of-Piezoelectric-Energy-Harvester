# %%
using DelimitedFiles
using CSV
using LaTeXStrings
using Plots
using DataFrames

# %%
# OFFSETM4 = readdlm("OFFSET_-0.4 _Plot.csv")
# OFFSETM5 = readdlm("OFFSET_-0.5 _Plot.csv");

OFFSETSHO = readdlm("OFFSET_NO_SHOLLE_Plot.csv")
OFFSETMD = readdlm("OFFSET_NO_MHOLLE_Plot.csv")
OFFSETBD = readdlm("OFFSET_NO_BHOLLE_Plot.csv");
OFFSETH = readdlm("OFFSET_NO_HOLLE_Plot.csv");
FORCE = readdlm("OFFSET_NO_HOLLE_Force.csv");
# OFFSETMD17 = readdlm("OFFSET_-0.0 _DIA 0.17 _Plot.csv");
# OFFSETMD20 = readdlm("OFFSET_-0.0 _DIA 0.2 _Plot.csv");

# %%
# Plot each line with a different line style and marker
plot(OFFSETSHO[:,1], OFFSETSHO[:,2], label="SMALL DIA", linestyle=:solid, marker=:asterisk, markersize=2.5)
plot!(OFFSETMD[:,1], OFFSETMD[:,2], label="MED DIA", linestyle=:dot, marker=:hexagon, markersize=2.5)
plot!(OFFSETH[:,1], OFFSETH[:,2], label="PERFECT BEAM", linestyle=:dash, marker=:diamond, markersize=2.5)

# Customize labels and style
xlabel!("time (s)")
ylabel!("Voltage (V)")
# Out:
# ┌ Warning: Skipped marker arg asterisk.
# └ @ Plots C:\Users\PRIYANSH\.julia\packages\Plots\sxUvK\src\args.jl:1149

# %%
plot(FORCE[:,1],FORCE[:,2],label="force")
xlabel!("time (s)")
ylabel!("Force (N)")
