# %%
using DelimitedFiles
using CSV
using LaTeXStrings
using Plots
using DataFrames

# %%
# OFFSETM4 = readdlm("OFFSET_-0.4 _Plot.csv")
# OFFSETM5 = readdlm("OFFSET_-0.5 _Plot.csv");

OFFSETNOHO = readdlm("OFFSET_NO_BHOLLE_Plot.csv")
OFFSETNOHOF = readdlm("OFFSET_NO_HOLLE_Force.csv")

# OFFSETMD13 = readdlm("OFFSET_-0.0 _DIA 0.13 _Plot.csv")
# OFFSETMD15 = readdlm("OFFSET_-0.0 _DIA 0.15 _Plot.csv");
# OFFSETMD17 = readdlm("OFFSET_-0.0 _DIA 0.17 _Plot.csv");
# OFFSETMD20 = readdlm("OFFSET_-0.0 _DIA 0.2 _Plot.csv");
# Out:
# 61×2 Matrix{Float64}:
#  0.0          0.0
#  0.00333333   0.187121
#  0.00666667   0.366063
#  0.01         0.529007
#  0.0133333    0.66883
#  0.0166667    0.779423
#  0.02         0.855951
#  0.0233333    0.89507
#  0.0266667    0.89507
#  0.03         0.855951
#  0.0333333    0.779423
#  0.0366667    0.66883
#  0.04         0.529007
#  ⋮
#  0.163333    -0.66883
#  0.166667    -0.779423
#  0.17        -0.855951
#  0.173333    -0.89507
#  0.176667    -0.89507
#  0.18        -0.855951
#  0.183333    -0.779423
#  0.186667    -0.66883
#  0.19        -0.529007
#  0.193333    -0.366063
#  0.196667    -0.187121
#  0.2         -4.40873e-16

# %%
plot(OFFSETNOHO[:,1],OFFSETNOHO[:,2],label="potential_diff")
# plot(OFFSETNOHOF[:,1],OFFSETNOHOF[:,2],label="force")
# plot(OFFSETNOHOF[:,1],OFFSETNOHOF[:,2],label=0.0)

# plot!(OFFSETMD13[:,1],-OFFSETMD13[:,2],label=0.13)
# plot!(OFFSETMD15[:,1],-OFFSETMD15[:,2],label=0.15)
# plot!(OFFSETMD17[:,1],-OFFSETMD17[:,2],label=0.17)
# plot!(OFFSETMD20[:,1],-OFFSETMD20[:,2],label=0.20)

# %%
plot(OFFSETNOHOF[:,1],OFFSETNOHOF[:,2],label="freq 20Hz amp 0.9")
